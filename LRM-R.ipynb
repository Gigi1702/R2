# %% [markdown]
# Linear regression in R

# %%
data = read.csv('regrex1.csv')

# %%
plot(data$x, data$y)
# Out:
# plot without title

# %%
lmData= lm(y~x, data = data)

# %%
lmData
# Out:
# Call:
# lm(formula = y ~ x, data = data)
#
# Coefficients:
# (Intercept)            x
#      2.2481       0.4691

# %%
summary(lmData)
# Out:
# Call:
# lm(formula = y ~ x, data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.66121 -0.53286 -0.02869  0.50436  2.36786
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  2.24814    0.29365   7.656 2.44e-08 ***
# x            0.46906    0.02444  19.194  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.8779 on 28 degrees of freedom
# Multiple R-squared:  0.9294,	Adjusted R-squared:  0.9268
# F-statistic: 368.4 on 1 and 28 DF,  p-value: < 2.2e-16

# %%
pred <- predict(lmData, data)

# %%
plot(data$x, data$y,)
lines(data$x, pred)
title('Linear regression Model R', xlab = 'X', ylab ='Y')
# Out:
# Plot with title “Linear regression Model R”
